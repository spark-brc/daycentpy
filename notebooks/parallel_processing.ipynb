# %%
import spotpy
import os
import sys

# %%
sys.path.insert(1, 'd:/Projects/Tools/daycentpy_git')

# %%
from daycentpy import dc_handler

# %%
wd = "d:/Projects/Tools/DayCent-CUTE/tools/dream_main"

# %%
m1 = dc_handler.DCinit(wd)

# %%
tt = m1.read_dc_pars()

# %%
dc_handler.demo_cali(wd)
# Out:
# Initializing the  DiffeRential Evolution Adaptive Metropolis (DREAM) algorithm  with  100  repetitions
# The objective function will be maximized
# Starting the DREAM algotrithm with 100 repetitions...
# Initialize  10  chain(s)...
# simulation
# 10
# evaluation
# 10
# 1 of 100, maximal objective function=-0.616295, time remaining: 00:12:25
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file 'DREAM_dc_nse_222.csv' created.
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# 10
# Beginn of Random Walk
# simulation
# 10
# evaluation
# 10
# 11 of 100, maximal objective function=0.503699, time remaining: 00:03:42
# simulation
# 10
# evaluation
# 10
# simulation
# 10
# evaluation
# ...

# %%
results = spotpy.analyser.

# %%
import sys
import os

# %%
sys.path.insert(0, 'D:/Projects/Tools/DayCent-CUTE')
import spotpy

# %%
sys.path.insert(0, 'D:/Projects/Tools/swatpy-master')
import swatpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [5], line 2
#       1 sys.path.insert(0, 'D:/Projects/Tools/swatpy-master')
# ----> 2 import swatpy
#
# ModuleNotFoundError: No module named 'swatpy'

# %%
spotpy.__version__
# Out:
# '1.6.1'

# %%
# %run -i "D:\Projects\Tools\DayCent-CUTE\spotpy\tutorials\tutorial_dream_hymod.py"
# Out:
# Initializing the  DiffeRential Evolution Adaptive Metropolis (DREAM) algorithm  with  5000  repetitions
# The objective function will be maximized
# Starting the DREAM algotrithm with 5000 repetitions...
# Initialize  7  chain(s)...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file 'DREAM_hymod.csv' created.
# Beginn of Random Walk
# D:\Projects/Tools/DayCent-CUTE\spotpy\algorithms\dream.py:238: RuntimeWarning: invalid value encountered in sqrt
#   R_stat = np.sqrt(
# D:\Projects/Tools/DayCent-CUTE\spotpy\algorithms\dream.py:111: RuntimeWarning: divide by zero encountered in double_scalars
#   gamma = 2.38 / np.sqrt(2 * nchain_pairs * d_star)  # /self.gammalevel
# Acceptance rates [%] =20.   26.67 33.33 33.33 40.   26.67 33.33
# Convergence rates =2.3284 2.8984 2.7061 1.8417 1.6753
# 113 of 5000, maximal objective function=-8411.53, time remaining: 00:01:26
# 317 of 5000, maximal objective function=-8308, time remaining: 00:00:59
# ...

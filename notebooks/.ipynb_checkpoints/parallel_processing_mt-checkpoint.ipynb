# %%
import spotpy
import os
import sys
import pandas as pd
import numpy as np
import subprocess
import shutil

# %%
sys.path.insert(1, 'd:/Projects/Tools/daycentpy_git')
# assert "dencentypy" in daycentpy.__file__

# %%
from daycentpy import handler
from daycentpy.models import multi_run

# %% [markdown]
# - Set a working directory as project folder
# - provide a path to your model folder

# %%
pwd = "d:/Projects/Tools/DayCent-CUTE/analysis/k-fold/mt_prj"
md = "d:/Projects/Tools/DayCent-CUTE/analysis/k-fold/DayCent_data_tmp/"

# %%
m1 = handler.MultiInit(pwd, md)
# Out:
#     We found DayCent parameter base file.
#     Open the file and select parameters you are goint to use ...,
#     then save it as 'seleted_pars.csv'.

# %%
sel_pars_df = m1.read_sel_dc_pars()
# Out:
# You have selected a total of 23 parameters.

# %%
m1.init_run()
# Out:
# **** Initial simulation begins ... ****
# Wooster ... passed: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:59<00:00, 11.88s/it]
# **** Initial simulation ends ... ****

# %%
df = m1.all_sim_obd()
df
# Out:
#     somsc_sim    site_name      treat_name  time      obd
# 0    4681.726  SCharleston  SCharleston_NT  1992  5125.00
# 1    5158.380  SCharleston  SCharleston_NT  2003  4730.00
# 2    4178.956  SCharleston  SCharleston_CT  1992  4573.40
# 3    4267.893  SCharleston  SCharleston_CT  2003  4090.00
# 4    4344.178  SCharleston  SCharleston_MT  1992  4677.10
# ..        ...          ...             ...   ...      ...
# 9    3382.937      Wooster   Wooster_cb_ct  1980  3036.05
# 10   3265.496      Wooster   Wooster_cb_ct  1992  2839.89
# 11   4533.036      Wooster   Wooster_cb_nt  1971  3714.00
# 12   4437.319      Wooster   Wooster_cb_nt  1980  3885.00
# 13   4308.061      Wooster   Wooster_cb_nt  1992  4266.28
#
# [75 rows x 5 columns]

# %%
from daycentpy import modules

# %%
wd = os.path.join(os.getcwd(), 'multi_main')

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\Tools\\DayCent-CUTE\\analysis\\k-fold\\mt_prj'

# %%
obs_m = df.obd.tolist()

# %%
from spotpy.likelihoods import gaussianLikelihoodMeasErrorOut as GausianLike

# %%
modules.multi_run_dream(wd, obs_m, sel_pars_df, 100, dbformat="ram", nChains=10, parallel="mpc", obj_func=GausianLike)
# Out:
# Initializing the  DiffeRential Evolution Adaptive Metropolis (DREAM) algorithm  with  100  repetitions
# The objective function will be maximized
# Starting the DREAM algotrithm with 100 repetitions...
# Initialize  10  chain(s)...
# 1 of 100, maximal objective function=-716.304, time remaining: 01:00:22
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# Beginn of Random Walk
# 11 of 100, maximal objective function=-648.469, time remaining: 00:18:08
# 21 of 100, maximal objective function=-636.251, time remaining: 00:13:13
# Acceptance rates [%] =100.  50. 100. 100. 100.  50.  50. 100. 100.  50.
# Convergence rates =1.6226 2.0339 1.9714 1.8937 2.3091 1.6294 5.4114 4.7867 3.4596 3.4496
#  4.2723 4.2028 2.4227 2.4225 2.4245 1.7715 2.651  2.7834 3.297  1.679
#  1.9669 1.5891 2.7343
# 31 of 100, maximal objective function=-636.251, time remaining: 00:10:33
# Acceptance rates [%] =100.    33.33 100.    66.67 100.    66.67  33.33  66.67  66.67  33.33
# Convergence rates =3.348  4.3261 4.2218 2.2369 4.6542 4.6057 0.1931    nan 3.0563 6.7881
#  1.7805 2.8997    nan 3.0881    nan 4.8956 4.9227 3.3061 2.6016 2.6942
#     nan 6.5426    nan
# C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\algorithms\dream.py:239: RuntimeWarning: invalid value encountered in sqrt
#   R_stat = np.sqrt(
# 41 of 100, maximal objective function=-636.251, time remaining: 00:08:32
# Acceptance rates [%] = 75.  25.  75.  75. 100.  50.  25.  50.  75.  50.
# Convergence rates =3.0518 2.1542 2.3147 2.6788 3.2757 2.6069 3.9248 2.7383 2.7631 3.5367
#  2.1381 2.3761 2.9136 2.3563 2.9137 3.235  2.2623 2.2788 3.0561 2.7367
#  2.3807 3.3762 3.1317
# 51 of 100, maximal objective function=-634.034, time remaining: 00:06:51
# Acceptance rates [%] =80. 20. 60. 60. 80. 60. 40. 40. 60. 60.
# Convergence rates =3.2123 2.2865 2.6584 7.0272 2.7851 2.8715 3.8849 2.6588 5.1009 2.4813
#  1.8934 2.9984 3.084  3.6588 2.486  2.669  2.0485 2.1721 3.0065 7.1958
#  2.5011 2.2089 2.6835
# 61 of 100, maximal objective function=-634.034, time remaining: 00:05:19
# Acceptance rates [%] =66.67 33.33 66.67 50.   66.67 50.   33.33 33.33 50.   50.
# Convergence rates =3.4123 2.577  2.832  8.07   2.8587 3.124  4.4552 3.0322 5.9548 2.3127
#  1.8367 3.3937 2.6703 4.2794 2.7036 2.9014 2.1827 2.4432 3.4283 6.5621
#  2.8901 2.2067 2.8989
# 71 of 100, maximal objective function=-634.034, time remaining: 00:03:52
# Acceptance rates [%] =71.43 28.57 57.14 42.86 71.43 57.14 28.57 28.57 42.86 57.14
# Convergence rates =4.323     nan 4.1349 3.1971 3.813  3.8697 0.0701 4.0634    nan 2.7349
#  2.4109    nan 1.8752    nan 5.5433 3.3263 3.5382 4.4421 2.2207 9.2987
#     nan 3.1501 5.8251
# 81 of 100, maximal objective function=-634.034, time remaining: 00:02:28
# Acceptance rates [%] =62.5 37.5 62.5 50.  62.5 62.5 25.  37.5 37.5 50.
# Convergence rates = 3.0295  4.2782  2.3903  2.3745  3.488   3.2435  6.2174  3.8002  3.8049
#   2.7178  1.8552  5.9833  1.6014  3.2244  5.4311  2.9559  2.9574  3.516
#  10.572   7.983   2.9081  3.0811  5.2979
# 91 of 100, maximal objective function=-629.197, time remaining: 00:01:05
# Stopping samplig
# Acceptance rates [%] =66.67 44.44 55.56 44.44 55.56 55.56 33.33 44.44 33.33 55.56
# Convergence rates =2.7659 3.1458 2.171  2.2214 5.1907 3.0697 3.4505 5.8167 3.1934 4.1631
#  1.8476 4.7939 1.4669 2.5009 8.9278 3.4552 3.5572 3.3882 8.7337 7.4209
#  2.0365 4.8905 4.3386
#
# *** Final SPOTPY summary ***
# Total Duration: 750.15 seconds
# Total Repetitions: 100
# Maximal objective value: -629.197
# Corresponding parameter setting:
# ANEREF(2): 4.92377
# ANEREF(3): 0.382395
# DEC3(2): 7.72353
# DEC4: 0.00469667
# DEC5(2): 0.0796527
# FWLOSS(4): 1.23964
# OMLECH(1): 0.671283
# P1CO2A(2): 0.109191
# P1CO2B(2): 0.551183
# P2CO2(2): 0.71135
# P3CO2: 0.659006
# PMCO2(2): 0.597422
# PS1CO2(2): 0.722876
# PS1S3(1): 0.00413553
# PS1S3(2): 0.0520754
# TEFF(1): 21.3779
# TEFF(2): 0.0786499
# WEFF(1): 29.0235
# WEFF(2): 9.78292
# dmp: 0.00744036
# dmpflux: 9.96478e-05
# FBM: 0.0358461
# FHP: 0.69942
# ******************************

# %%
sim_df = pd.DataFrame()
for i in range(mlines[0]):
    # start_yr, end_yr = self.get_start_end_years(data[i][1])
    outf = data[i][1]+".lis"
    df = pd.read_csv( outf, sep=r'\s+', skiprows=1)
    cali_start = 1971
    cali_end = 2003
    # daycent time shift
    cali_sshift = cali_start + .08
    cali_eshift = cali_end + 1.00
    df_sel = df.loc[(df['time']>=cali_sshift) & (df['time']<=cali_eshift)]
    df_sel.index = pd.date_range(start='1/1/{}'.format(cali_start), periods=len(df_sel), freq='M')
    dfa = df_sel.loc[:, ['somsc']].resample('A').mean()
    dfa['site_name'] = 'sidney'
    dfa['treat_name'] = data[i][1]
    dfa['time'] = dfa.index.year
    dfa.rename(columns = {'somsc':'somsc_sim'}, inplace = True)
    sim_df = pd.concat([sim_df, dfa], axis=0)

# get all obds
obd_f = "soc_obd.csv"
obd_df = pd.read_csv(obd_f) 
obd_df.replace(-999, np.nan, inplace=True)



for i in range(len(sim_df)):
    tn = sim_df.treat_name[i]
    tm = sim_df.time[i]
    if obd_df[tn].loc[obd_df['Year']==tm].size > 0:
        sim_df.loc[(sim_df["treat_name"]==tn) & (sim_df["time"]==tm), 'obd'] = obd_df[tn].loc[obd_df['Year']==tm].values[0] 
sim_df = sim_df.dropna(axis=0)
sim_df.to_csv("sim_obd.csv", index=False, float_format='%.3f')



# for i in range(len(sim_df)):
#     tn = sim_df.treat_name[i]
#     tm = sim_df.time[i]
#     sim_df.loc[(sim_df["treat_name"]==tn) & (sim_df["time"]==tm), 'obd'] = obd_df[tn].loc[obd_df['Year']==tm].values[0] 
# sim_df = sim_df.dropna(axis=0)
# sim_df.to_csv("sim_obd.csv", index=False, float_format='%.3f')

# %%
if obd_df["SCharleston_CT"].loc[obd_df["Year"]==1972].size >0:
    print('hi')
else:
    print('noe')
# Out:
# noe

# %%
if obd_df["SCharleston_CT"].loc[obd_df["Year"]==1972].values:
    print('test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 if obd_df["SCharleston_CT"].loc[obd_df["Year"]==1972]:
#       2     print('test')
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
if obd_df["SCharleston_CT"].loc[obd_df["Year"]==1972]:
    print('nope')
else:
    print('yes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 if obd_df["SCharleston_CT"].loc[obd_df["Year"]==1972]:
#       2     print('nope')
#       3 else:
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
 obd_df[tn].loc[obd_df['Year']==tm]
# Out:
#               somsc_sim site_name      treat_name  time     obd
# 1971-12-31  3651.877250    sidney  SCharleston_NT  1971  3729.4
# 1972-12-31  3730.965833    sidney  SCharleston_NT  1972     NaN
# 1973-12-31  3770.341417    sidney  SCharleston_NT  1973     NaN
# 1974-12-31  3802.381167    sidney  SCharleston_NT  1974     NaN
# 1975-12-31  3839.693417    sidney  SCharleston_NT  1975     NaN
# ...                 ...       ...             ...   ...     ...
# 1999-12-31  4420.448500    sidney  SCharleston_MT  1999     NaN
# 2000-12-31  4432.014500    sidney  SCharleston_MT  2000     NaN
# 2001-12-31  4436.691167    sidney  SCharleston_MT  2001     NaN
# 2002-12-31  4449.835333    sidney  SCharleston_MT  2002     NaN
# 2003-12-31  4446.894750    sidney  SCharleston_MT  2003     NaN
#
# [99 rows x 5 columns]

# %%
obd_df
# Out:
#    Year  SCharleston_CT  SCharleston_MT  SCharleston_NT
# 0  1971          3520.6          3625.0          3729.4
# 1  1992          4573.4          4677.1          5125.0
# 2  2003          4090.0          4120.0          4730.0

# %%
obd_f
# Out:
# 'soc_obd.csv'

# %%
sim_df.loc[(sim_df["treat_name"]=='Sidney_BF') & (sim_df["time"]==1993), 'obd'] = obd_df['Sidney_BF'].loc[obd_df['Year']==1993].values[0]

# %%
obd_df['Sidney_BF'].loc[obd_df['Year']==1993].values[0]
# Out:
# 3920

# %%
nam_ex
# Out:
# 7

# %%
sim_df
# Out:
#               somsc_sim site_name treat_name  time     obd
# 1993-12-31  3940.352917    sidney  Sidney_BF  1993  3920.0
# 1993-12-31  4785.250083    sidney  Sidney_NT  1993     NaN
# 1993-12-31  4582.889000    sidney  Sidney_SM  1993     NaN

# %%
sim_df.loc[(sim_df["treat_name"]=='Sidney_BF') & (sim_df["time"]==1993), 'obd'] = 1

# %%
sim_df
# Out:
#               somsc_sim site_name treat_name  time  obd
# 1993-12-31  3940.352917    sidney  Sidney_BF  1993  1.0
# 1993-12-31  4785.250083    sidney  Sidney_NT  1993  NaN
# 1993-12-31  4582.889000    sidney  Sidney_SM  1993  NaN

# %%
dc_handler.run_dream(wd, sel_pars_df, "mpc", 2000, 20)
# Out:
# Initializing the  Shuffled Complex Evolution (SCE-UA) algorithm  with  2000  repetitions
# The objective function will be minimized
# Starting burn-in sampling...
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\multiprocess\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\multiprocess\pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\pathos\helpers\mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#                         ^^^^^^^^
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\parallel\mproc.py", line 49, in f
#     data = self.process(job)
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\algorithms\sceua.py", line 72, in simulate
#     return _algorithm.simulate(self, id_params_tuple)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\seonggyu.park\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\algorithms\_algorithm.py", line 546, in simulate
#     model_result = self.setup.simulation(self.partype(*all_params))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Projects/Tools/daycentpy_git\daycentpy\dc_handler.py", line 475, in simulation
#     self.saving_results(obj_val, cpars, sim_list)
#   File "d:\Projects/Tools/daycentpy_git\daycentpy\dc_handler.py", line 517, in saving_results
#     with open(os.path.join(self.wd, dbfile), 'a') as inf:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# PermissionError: [Errno 13] Permission denied: 'd:\\Projects\\Tools\\DayCent-CUTE\\analysis\\cali\\main\\db_results.csv'
# """
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dc_handler.run_dream(wd, sel_pars_df, "mpc", 2000, 20)
#
# File d:\Projects/Tools/daycentpy_git\daycentpy\dc_handler.py:539, in run_dream(wd, pars_df, parallel, rep, ngs)
#     537 sampler = spotpy.algorithms.sceua(spot_setup, dbname="SCEUA_hymod", dbformat="csv", parallel='mpc')
#     538 # Start the sampler, one can specify ngs, kstop, peps and pcento id desired
# --> 539 sampler.sample(rep, ngs=ngs, kstop=3, peps=0.1, pcento=0.1)
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\algorithms\sceua.py:213, in sceua.sample(self, repetitions, ngs, kstop, pcento, peps, max_loop_inc)
#     211 # Burn in
#     212 param_generator = ((rep, x[rep]) for rep in range(int(npt)))
# --> 213 for rep, randompar, simulations in self.repeat(param_generator):
#     214     # Calculate the objective function
#     215     like = self.postprocessing(icall, randompar, simulations, chains=0)
#     216     xf[rep] = like
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\spotpy\parallel\mproc.py:53, in ForEach.__call__(self, jobs)
#      52 def __call__(self, jobs):
# ---> 53     results = self.pool.map(self.f, jobs)
#      54     for i in results:
#      55         yield i
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\pathos\multiprocessing.py:135, in ProcessPool.map(self, f, *args, **kwds)
#     133 AbstractWorkerPool._AbstractWorkerPool__map(self, f, *args, **kwds)
#     134 _pool = self._serve()
# --> 135 return _pool.map(star(f), zip(*args))
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\multiprocess\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\Miniconda3\envs\daycentpy\Lib\site-packages\multiprocess\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# PermissionError: [Errno 13] Permission denied: 'd:\\Projects\\Tools\\DayCent-CUTE\\analysis\\cali\\main\\db_results.csv'

# %%
dc_handler.demo_cali(wd, sel_pars_df)
# Out:
# Initializing the  DiffeRential Evolution Adaptive Metropolis (DREAM) algorithm  with  2000  repetitions
# The objective function will be minimized
# Starting the DREAM algotrithm with 2000 repetitions...
# Initialize  10  chain(s)...
# simulation
# 14
# evaluation
# 14
# 1 of 2000, minimal objective function=8.18172, time remaining: 05:41:57
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file 'DREAM_dc_bias.csv' created.
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Beginn of Random Walk
# simulation
# 14
# evaluation
# 14
# 11 of 2000, minimal objective function=0.139615, time remaining: 01:53:15
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# 21 of 2000, minimal objective function=0.139615, time remaining: 01:32:45
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =  0.  50.  50. 100. 100.  50. 100.  50.  50.   0.
# Convergence rates =2.6854 5.0568 3.6855 3.2051 3.9956 4.2056 4.4064 3.824  5.2413 4.3234
#  3.9461 3.9551 4.5502 3.6526 3.2304 4.8392 4.6712 2.9702 4.5295 4.0372
#  4.3377 4.1381 3.3512 3.6376 5.9225 4.7659 2.1841 4.0882 4.0512
# simulation
# 14
# evaluation
# 14
# 31 of 2000, minimal objective function=0.139615, time remaining: 01:23:08
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] = 33.33  66.67  66.67 100.   100.    33.33  66.67  33.33  66.67   0.
# Convergence rates =1.6629 2.9979 3.3923 1.56   3.2675 6.4905 2.2414 1.4893 1.8037 2.6249
#  5.1837 1.6577 3.9563 2.8445 3.6526 3.2968 2.8668 2.3338 3.3897 1.8479
#  2.9295 2.0414 2.6129 1.7043 4.6017 4.0116 2.1474 2.7211 3.6119
# simulation
# 14
# evaluation
# 14
# 41 of 2000, minimal objective function=0.139615, time remaining: 01:16:15
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] = 50.  75.  50.  75. 100.  25.  75.  50.  75.  25.
# Convergence rates =1.8115 3.7071 3.0595 1.8225 3.7119 7.912  2.0098 1.5402 2.1479 1.945
#  2.277  1.9235 4.9639 3.437  4.4347 4.1236 2.2715 2.3381 2.5508 1.791
#  3.6102 1.7487 3.1475 1.915  2.2405 4.5127 2.5037 3.1983 2.3641
# simulation
# 14
# evaluation
# 14
# 51 of 2000, minimal objective function=0.139615, time remaining: 01:12:07
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =60. 80. 40. 80. 80. 20. 80. 60. 80. 40.
# Convergence rates =3.2977 3.682  1.9499 2.6048 6.3807 2.4326 1.9499 2.1662 1.8664 2.2818
#  2.3147 4.7813 1.9596 4.3165 4.1099 3.8008 2.5929 3.4722 2.122  2.1101
#  2.0491 2.2864 3.0061 8.18   1.9963 3.6962 2.6065 5.4504 2.5899
# simulation
# 14
# evaluation
# 14
# 61 of 2000, minimal objective function=0.139615, time remaining: 01:09:09
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =50.   66.67 50.   66.67 66.67 33.33 83.33 66.67 66.67 33.33
# Convergence rates =3.738  2.8719 1.718  2.5014 2.9939 2.5103 1.564  2.1296 1.8306 2.5269
#  2.4951 2.3068 1.6677 4.232  3.8526 2.6327 2.4252 2.6451 1.6937 2.1299
#  1.65   2.5433 2.9466 3.0091 1.8902 3.8419 2.6431 3.3594 2.5853
# simulation
# 14
# evaluation
# 14
# 71 of 2000, minimal objective function=0.139615, time remaining: 01:06:54
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =57.14 71.43 57.14 71.43 71.43 42.86 85.71 57.14 71.43 42.86
# Convergence rates =2.3036 1.8617 1.7215 1.87   2.5354 1.7433 1.31   2.1871 2.0661 6.1241
#  2.7537 1.5643 1.5145 1.959  4.3212 1.6032 2.4107 2.6418 1.7132 2.0553
#  1.5096 1.9239 2.152  2.5307 2.3049 1.8647 2.6715 3.1988 2.1934
# simulation
# 14
# evaluation
# 14
# 81 of 2000, minimal objective function=0.139615, time remaining: 01:05:09
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =62.5 62.5 62.5 62.5 75.  37.5 87.5 62.5 62.5 37.5
# Convergence rates =2.0181 1.8045 1.8081 1.802  2.697  1.6087 1.2916 2.2265 2.1734 5.787
#  2.419  1.5219 1.5379 1.7701 3.8549 1.4668 2.2834 2.4414 1.7607 1.9873
#  1.5305 1.7684 2.008  2.5941 2.3481 1.746  2.7532 2.8047 2.2042
# simulation
# 14
# evaluation
# 14
# 91 of 2000, minimal objective function=0.139615, time remaining: 01:03:43
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%]
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =61.73 64.8  46.94 58.16 60.2  52.55 58.67 46.43 61.73 54.08
# Convergence rates =1.2657 1.3913 1.2184 1.5029 1.4952 1.088  1.0983 1.2913 1.1612 1.1758
#  1.1255 1.3446 1.2296 1.5292 1.1982 1.2182 1.2309 1.3194 1.3476 1.3415
#  1.4132 1.1662 1.2243 1.2367 1.0939 1.2891 1.3684 1.3352 1.2871
# simulation
# 14
# evaluation
# 14
# 1971 of 2000, minimal objective function=0.139615, time remaining: 00:00:49
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =61.42 64.97 46.7  58.38 60.41 52.79 58.88 46.19 61.93 54.31
# Convergence rates =1.2725 1.3905 1.2195 1.5019 1.5019 1.0854 1.0928 1.3007 1.1601 1.1854
#  1.123  1.3552 1.235  1.5398 1.2012 1.219  1.2445 1.3222 1.3479 1.3433
#  1.4214 1.1676 1.2227 1.2402 1.1001 1.2913 1.3682 1.3367 1.2908
# simulation
# 14
# evaluation
# 14
# 1981 of 2000, minimal objective function=0.139615, time remaining: 00:00:31
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Acceptance rates [%] =61.62 64.65 46.46 58.59 60.1  52.53 58.59 45.96 62.12 54.04
# Convergence rates =1.2698 1.3849 1.2182 1.4988 1.5034 1.0833 1.0893 1.297  1.1588 1.1884
#  1.1221 1.3541 1.2327 1.5441 1.2036 1.2168 1.2438 1.3227 1.3464 1.3395
#  1.4241 1.1654 1.2205 1.2432 1.101  1.2866 1.3615 1.3352 1.2805
# simulation
# 14
# evaluation
# 14
# 1991 of 2000, minimal objective function=0.139615, time remaining: 00:00:14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# simulation
# 14
# evaluation
# 14
# Stopping samplig
# Acceptance rates [%] =61.31 64.82 46.23 58.79 60.3  52.26 58.79 45.73 61.81 53.77
# Convergence rates =1.2771 1.3819 1.2185 1.4926 1.5105 1.081  1.0849 1.3044 1.1584 1.1993
#  1.1206 1.3601 1.2363 1.5522 1.2068 1.2186 1.2568 1.3281 1.3497 1.3417
#  1.432  1.168  1.2202 1.2437 1.107  1.2868 1.3614 1.3364 1.2825
#
# *** Final SPOTPY summary ***
# Total Duration: 3468.65 seconds
# Total Repetitions: 2000
# Minimal objective value: 0.139615
# Corresponding parameter setting:
# ANEREF(1): 1.05441
# ANEREF(2): 4.61446
# ANEREF(3): 0.742454
# DAMR(1_1): 0.0613297
# DAMRMN(1): 17.6518
# DEC1(1): 4.41645
# DEC1(2): 5.02355
# DEC2(1): 16.3042
# DEC2(2): 17.7845
# DEC3(1): 4.45323
# DEC3(2): 6.14961
# DEC4: 0.00276082
# DEC5(2): 0.120904
# FWLOSS(4): 1.06574
# OMLECH(1): 0.224692
# P1CO2A(2): 0.114008
# P1CO2B(2): 0.694187
# TEFF(1): 22.5482
# TEFF(2): 0.129174
# WEFF(1): 30.4265
# WEFF(2): 12.0737
# dmp: 0.00140155
# dmpflux: 7.68011e-05
# N2Oadjust_fc: 0.735378
# N2Oadjust_wp: 0.870441
# N2N2Oadj: 1.42587
# FBM: 0.0268732
# FHP: 0.696665
# Till_Eff: 5.6384
# ******************************
#
# d:\Projects\Tools\DayCent-CUTE\analysis\cali\main
